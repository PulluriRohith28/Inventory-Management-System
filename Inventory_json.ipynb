# %%
{"1": {"Product Name": "MacBook Air", "Product Category": "Laptop", "Product Price": 165980, "Product Rating": 5, "Product Inventory": 100}, "2": {"Product Name": "HP Spectre x360 14", "Product Category": "Laptop", "Product Price": 79855, "Product Rating": 5, "Product Inventory": 100}, "3": {"Product Name": "LG Gram 17", "Product Category": "Laptop", "Product Price": 49875, "Product Rating": 5, "Product Inventory": 100}, "4": {"Product Name": "HP Envy x360", "Product Category": "Laptop", "Product Price": 54912, "Product Rating": 5, "Product Inventory": 100}, "5": {"Product Name": "MacBook Pro 13", "Product Category": "Laptop", "Product Price": 85632, "Product Rating": 5, "Product Inventory": 100}, "6": {"Product Name": "Dell XPS 13 2-in-1", "Product Category": "Laptop", "Product Price": 65874, "Product Rating": 5, "Product Inventory": 100}, "7": {"Product Name": "Dell XPS 13", "Product Category": "Laptop", "Product Price": 90036, "Product Rating": 5, "Product Inventory": 100}, "8": {"Product Name": "Asus ROG Zephyrus G15", "Product Category": "Laptop", "Product Price": 132659, "Product Rating": 5, "Product Inventory": 100}, "9": {"Product Name": "Lenovo ThinkPad X1 Nano", "Product Category": "Laptop", "Product Price": 50365, "Product Rating": 5, "Product Inventory": 100}, "10": {"Product Name": "Asus ROG Zephyrus G14", "Product Category": "Laptop", "Product Price": 120365, "Product Rating": 5, "Product Inventory": 100}, "11": {"Product Name": "MacBook Pro", "Product Category": "Laptop", "Product Price": 160000, "Product Rating": 5, "Product Inventory": 100}, "12": {"Product Name": "HP Elite Dragonfly", "Product Category": "Laptop", "Product Price": 45987, "Product Rating": 5, "Product Inventory": 100}, "13": {"Product Name": "Lenovo\u2019s Chromebook Duet", "Product Category": "Laptop", "Product Price": 126598, "Product Rating": 5, "Product Inventory": 100}, "14": {"Product Name": "Razer Book 13", "Product Category": "Laptop", "Product Price": 140256, "Product Rating": 5, "Product Inventory": 100}, "15": {"Product Name": "Lenovo Yoga 9i", "Product Category": "Laptop", "Product Price": 52287, "Product Rating": 5, "Product Inventory": 100}, "16": {"Product Name": "Dell Inspiron 14 Laptop", "Product Category": "Laptop", "Product Price": 70265, "Product Rating": 5, "Product Inventory": 100}, "17": {"Product Name": "Lenovo ThinkBook 14", "Product Category": "Laptop", "Product Price": 60000, "Product Rating": 5, "Product Inventory": 100}, "18": {"Product Name": "HP 245 G7", "Product Category": "Laptop", "Product Price": 125000, "Product Rating": 5, "Product Inventory": 100}, "19": {"Product Name": "Samsung Galaxy Z Flip3 5G", "Product Category": "Mobile", "Product Price": 32987, "Product Rating": 5, "Product Inventory": 100}, "20": {"Product Name": "OnePlus Nord CE 5G", "Product Category": "Mobile", "Product Price": 45698, "Product Rating": 5, "Product Inventory": 100}, "21": {"Product Name": "Galaxy Z Fold3 5G", "Product Category": "Mobile", "Product Price": 67548, "Product Rating": 5, "Product Inventory": 100}, "22": {"Product Name": "OnePlus 9R 5G", "Product Category": "Mobile", "Product Price": 55008, "Product Rating": 5, "Product Inventory": 100}, "23": {"Product Name": "OnePlus 9 5G", "Product Category": "Mobile", "Product Price": 50002, "Product Rating": 5, "Product Inventory": 100}, "24": {"Product Name": "Samsung Galaxy Note 20", "Product Category": "Mobile", "Product Price": 69832, "Product Rating": 5, "Product Inventory": 100}, "25": {"Product Name": "Motorola Edge+", "Product Category": "Mobile", "Product Price": 40000, "Product Rating": 5, "Product Inventory": 100}, "26": {"Product Name": "Vivo V21 5G", "Product Category": "Mobile", "Product Price": 50000, "Product Rating": 5, "Product Inventory": 100}, "27": {"Product Name": "Google Pixel 4a", "Product Category": "Mobile", "Product Price": 42420, "Product Rating": 5, "Product Inventory": 100}, "28": {"Product Name": "Asus Rog Phone 3", "Product Category": "Mobile", "Product Price": 49999, "Product Rating": 5, "Product Inventory": 100}, "29": {"Product Name": "Samsung Galaxy S10+", "Product Category": "Mobile", "Product Price": 69448, "Product Rating": 5, "Product Inventory": 100}, "30": {"Product Name": "Google - Pixel 4", "Product Category": "Mobile", "Product Price": 53007, "Product Rating": 5, "Product Inventory": 100}}
# Out:
# {'1': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'MacBook Air',
#   'Product Price': 165980,
#   'Product Rating': 5},
#  '10': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'Asus ROG Zephyrus G14',
#   'Product Price': 120365,
#   'Product Rating': 5},
#  '11': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'MacBook Pro',
#   'Product Price': 160000,
#   'Product Rating': 5},
#  '12': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'HP Elite Dragonfly',
#   'Product Price': 45987,
#   'Product Rating': 5},
#  '13': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'Lenovo’s Chromebook Duet',
#   'Product Price': 126598,
#   'Product Rating': 5},
#  '14': {'Product Category': 'Laptop',
#   'Product Inventory': 100,
#   'Product Name': 'Razer Book 13',
#   'Product Price': 140256,
#   'Product Rating': 5},
# ...
